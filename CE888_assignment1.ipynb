# %%
import pandas as pd
df= pd.read_csv("NatRep_Online_Upload.csv")
print (df)
# Out:
#        ﻿ID  Voting_Intention  EUREF_Int  EUREF_SQUEEZE  EUREF_likely  \
# 0        1                 1          1              9            11
# 1        2                 9          2              9            11
# 2        3                 4          2              9            11
# 3        4                 1          1              9            11
# 4        5                 2          1              9            11
# 5        6                 1          2              9            11
# 6        7                 1          2              9            11
# 7        8                 3          1              9            11
# 8        9                 2          1              9            11
# 9       10                 9          1              9             6
# 10      11                 9          1              9            11
# 11      12                 2          1              9            11
# 12      13                 2          1              9            11
# ...
